# %%
# open CV image opening

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import cv2

# %%
img =cv2.imread('IMG_2441.JPG')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
#img

# %%
plt.imshow(img)          # bcoz now it is in format BGR

# %%
img_crctn=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img_crctn
# Out:
# array([[[236, 254, 255],
#         [236, 254, 255],
#         [236, 254, 255],
#         ...,
#         [238, 253, 255],
#         [238, 253, 255],
#         [237, 252, 255]],
#
#        [[236, 254, 255],
#         [236, 254, 255],
#         [236, 254, 255],
#         ...,
#         [238, 253, 255],
#         [238, 253, 255],
#         [237, 252, 255]],
#
#        [[236, 254, 255],
#         [236, 254, 255],
#         [236, 254, 255],
#         ...,
#         [238, 253, 255],
#         [238, 253, 255],
#         [237, 252, 255]],
#
#        ...,
#
#        [[ 29,  33,  36],
#         [ 26,  30,  33],
#         [ 27,  31,  34],
#         ...,
#         [ 33,  40,  48],
#         [ 33,  40,  48],
#         [ 33,  40,  48]],
#
#        [[ 29,  33,  36],
#         [ 26,  30,  33],
#         [ 26,  30,  33],
#         ...,
#         [ 35,  42,  50],
#         [ 34,  41,  49],
#         [ 33,  40,  48]],
#
#        [[ 28,  32,  35],
#         [ 25,  29,  32],
#         [ 25,  29,  32],
# ...

# %%
plt.imshow(img_crctn)

# %%
plt.imshow(img_crctn,cmap='gray')

# %%
plt.imshow(img_crctn[:,:,0],'gray')

# %%
plt.imshow(img_crctn[:,:,0],'coolwarm')

# %%
plt.imshow(img_crctn[:,:,0],'magma')

# %%
fig=plt.figure(figsize=(6,10))
ax=fig.add_subplot(111)
ax.imshow(img_crctn[:,:,0])

# %% [markdown]
# # cv2   open cv

# %%
img=cv2.imread('IMG_2441.JPG')

# %%
img
# Out:
# array([[[255, 254, 236],
#         [255, 254, 236],
#         [255, 254, 236],
#         ...,
#         [255, 253, 238],
#         [255, 253, 238],
#         [255, 252, 237]],
#
#        [[255, 254, 236],
#         [255, 254, 236],
#         [255, 254, 236],
#         ...,
#         [255, 253, 238],
#         [255, 253, 238],
#         [255, 252, 237]],
#
#        [[255, 254, 236],
#         [255, 254, 236],
#         [255, 254, 236],
#         ...,
#         [255, 253, 238],
#         [255, 253, 238],
#         [255, 252, 237]],
#
#        ...,
#
#        [[ 36,  33,  29],
#         [ 33,  30,  26],
#         [ 34,  31,  27],
#         ...,
#         [ 48,  40,  33],
#         [ 48,  40,  33],
#         [ 48,  40,  33]],
#
#        [[ 36,  33,  29],
#         [ 33,  30,  26],
#         [ 33,  30,  26],
#         ...,
#         [ 50,  42,  35],
#         [ 49,  41,  34],
#         [ 48,  40,  33]],
#
#        [[ 35,  32,  28],
#         [ 32,  29,  25],
#         [ 32,  29,  25],
# ...

# %%
img_cvt=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
#img_cvt

# %%
img_gray=cv2.imread('IMG_2441.JPG',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(cv2.imread('IMG_2441.JPG',cv2.IMREAD_GRAYSCALE),cmap='gray')

# %%
img_re = cv2.resize(img_cvt,(300,500))

# %%
plt.imshow(img_re)

# %%
w_ratio=0.5
h_ratio=0.5
# need to fill for ratio method

# %%
# flip method uses 0,1,-1

# %%
plt.imshow(cv2.flip(img_cvt,1))

# %%
plt.imshow(cv2.flip(img_cvt,-1))

# %%
plt.imshow(cv2.flip(img_cvt,0))

# %%
cv_flip=cv2.flip(img_cvt,0)

# %%
plt.imshow(cv2.flip(cv_flip,-1))

# %%
#single line
plt.imshow(cv2.flip(cv2.flip(img_cvt,0),-1))

# %%
cv2.imwrite('new_img.jpg',img_cvt)
# Out:
# True

# %%
plt.imshow(cv2.imread('new_img.jpg'))

# %%
cv2.imshow('mahab',img_cvt)
cv2.waitKey()
